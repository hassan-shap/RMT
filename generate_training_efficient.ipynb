# %%
import numpy as np
from quimb import *
import quimb.tensor as qtn
from quimb.tensor import *
import csv
import time
from numpy.linalg import matrix_power

# %%
N = 10
bond_dims  = [2,4,8,16,32,64,999]
runs = 1

with open('training_data_N_%d_abcd.csv' % (N), mode='a') as training_data:
 
    for i in np.arange(runs):
        t = time.time()
        dims = [2] * N
        D = prod(dims)
        NAs = np.arange(2, N+1)
        for bond_dim in bond_dims:
            if bond_dim == 999:
                
                randket= rand_haar_state(D)
            
            else:
                randket= rand_matrix_product_state(N, bond_dim, phys_dim=2, dtype=complex, cyclic=True, trans_invar=False)
            
            for NA in NAs:
                    
                randstate = ptr(randket, dims, np.arange(NA))
                NA1s = np.arange(1, NA)
                for NA1 in NA1s:
                    NA2 = int(NA - NA1)
                    NB = int(N - NA)

                    randstate_pt = partial_transpose(randstate, [2] * NA, sysa=np.arange(NA1))
                    
                    LN = logneg_subsys(randket, dims, np.arange(NA1), np.arange(NA1,NA))

                    r2 = np.dot(randstate_pt, randstate_pt)
                    r3 = np.dot(r2, randstate_pt)
                    r4 = np.dot(r3, randstate_pt)
                    r5 = np.dot(r4, randstate_pt)
                    r6 = np.dot(r5, randstate_pt)
                    r7 = np.dot(r6, randstate_pt)
                    r8 = np.dot(r7, randstate_pt)
                    
                    p2 = np.real(np.trace(r2))
                    p3 = np.real(np.trace(r3))
                    p4 = np.real(np.trace(r4))
                    p5 = np.real(np.trace(r5))
                    p6 = np.real(np.trace(r6))
                    p7 = np.real(np.trace(r7))
                    p8 = np.real(np.trace(r8))
                
                    
                    #Writing to file
                    training_writer = csv.writer(training_data, delimiter=',')
                    training_writer.writerow([NA1,NA2,NB,p2,p3,p4,p5,p6,p7,p8,LN])
                    
        print('Round:',i+1, round(time.time()-t,3), 'seconds')
    
    
print("Done!")
# Out:
# Round: 1 35.506 seconds
# Done!

# %%
N = 10
bond_dims  = [2,4,8,16,32,64,999]
runs = 100

with open('training_data_N_%d_eff.csv' % (N), mode='a') as training_data:
 
    for i in np.arange(runs):
        t = time.time()
        dims = [2] * N
        D = prod(dims)
        NAs = np.arange(2, N+1)
        for bond_dim in bond_dims:
            if bond_dim == 999:
                
                randket= rand_haar_state(D)
            
            else:
                randket= rand_matrix_product_state(N, bond_dim, phys_dim=2, dtype=complex, cyclic=True, trans_invar=False)
            
            for NA in NAs:
                NB = int(N - NA)
                randstate = ptr(randket, dims, np.arange(NA))
                if NA<N:
                    NA1s = np.arange(1, NA)
                    for NA1 in NA1s:
                        NA2 = int(NA - NA1)

                        LN = logneg_subsys(randket, dims, np.arange(NA1), np.arange(NA1,NA))

                        randstate_pt = partial_transpose(randstate, [2] * NA, sysa=np.arange(NA1))
                        r2 = np.dot(randstate_pt, randstate_pt)
                        r3 = np.dot(r2, randstate_pt)
                        r4 = np.dot(r3, randstate_pt)
                        r5 = np.dot(r4, randstate_pt)
                        r6 = np.dot(r5, randstate_pt)
                        r7 = np.dot(r6, randstate_pt)
                        r8 = np.dot(r7, randstate_pt)

                        p2 = np.real(np.trace(r2))
                        p3 = np.real(np.trace(r3))
                        p4 = np.real(np.trace(r4))
                        p5 = np.real(np.trace(r5))
                        p6 = np.real(np.trace(r6))
                        p7 = np.real(np.trace(r7))
                        p8 = np.real(np.trace(r8))
                        
                        #Writing to file
                        training_writer = csv.writer(training_data, delimiter=',')
                        training_writer.writerow([NA1,NA2,NB,p2,p3,p4,p5,p6,p7,p8,LN])
                else:
                    NA1s = np.arange(1, NA)
                    for NA1 in NA1s:
                        NA2 = int(NA - NA1)

                        LN = logneg_subsys(randket, dims, np.arange(NA1), np.arange(NA1,NA))

                        rA1 = partial_trace(randstate, [2]*NA , keep=np.arange(NA1))
                        r2 = np.dot(rA1, rA1)
                        r3 = np.dot(r2, rA1)
                        r4 = np.dot(r3, rA1)
                        r5 = np.dot(r4, rA1)
                        r6 = np.dot(r5, rA1)
                        r7 = np.dot(r6, rA1)

                        p2 = np.real(np.trace(rA1))
                        p3 = np.real(np.trace(r3))
                        p4 = np.real(np.trace(r2))**2
                        p5 = np.real(np.trace(r5))
                        p6 = np.real(np.trace(r3))**2
                        p7 = np.real(np.trace(r7))
                        p8 = np.real(np.trace(r4))**2
                
                    
                        #Writing to file
                        training_writer = csv.writer(training_data, delimiter=',')
                        training_writer.writerow([NA1,NA2,NB,p2,p3,p4,p5,p6,p7,p8,LN])

        print('Round:',i+1, round(time.time()-t,3), 'seconds')
    
    
print("Done!")
# Out:
# Round: 1 4.386 seconds
# Round: 2 4.359 seconds
# Round: 3 4.302 seconds
# Round: 4 4.62 seconds
# Round: 5 4.177 seconds
# Round: 6 4.208 seconds
# Round: 7 4.412 seconds
# Round: 8 5.043 seconds
# Round: 9 4.192 seconds
# Round: 10 4.632 seconds
# Round: 11 4.814 seconds
# Round: 12 4.677 seconds
# Round: 13 5.011 seconds
# Round: 14 4.276 seconds
# Round: 15 5.482 seconds
# Round: 16 11.73 seconds
# Round: 17 62.412 seconds
# Round: 18 11.957 seconds
# Round: 19 4.445 seconds
# Round: 20 4.308 seconds
# Round: 21 4.504 seconds
# Round: 22 4.515 seconds
# Round: 23 4.303 seconds
# Round: 24 4.427 seconds
# Round: 25 4.308 seconds
# Round: 26 4.422 seconds
# Round: 27 4.126 seconds
# Round: 28 4.365 seconds
# Round: 29 4.28 seconds
# Round: 30 4.301 seconds
# Round: 31 4.224 seconds
# Round: 32 4.251 seconds
# Round: 33 4.387 seconds
# Round: 34 4.358 seconds
# Round: 35 4.229 seconds
# Round: 36 4.599 seconds
# Round: 37 4.0 seconds
# Round: 38 4.398 seconds
# Round: 39 4.097 seconds
# Round: 40 4.383 seconds
# Round: 41 4.29 seconds
# Round: 42 4.099 seconds
# Round: 43 4.147 seconds
# Round: 44 4.265 seconds
# Round: 45 4.204 seconds
# Round: 46 4.496 seconds
# Round: 47 4.354 seconds
# Round: 48 4.282 seconds
# Round: 49 4.295 seconds
# Round: 50 4.343 seconds
# Round: 51 4.663 seconds
# Round: 52 4.333 seconds
# Round: 53 4.422 seconds
# Round: 54 4.252 seconds
# Round: 55 4.417 seconds
# Round: 56 4.016 seconds
# Round: 57 4.626 seconds
# Round: 58 4.28 seconds
# Round: 59 4.995 seconds
# Round: 60 4.162 seconds
# Round: 61 4.389 seconds
# Round: 62 4.346 seconds
# Round: 63 4.326 seconds
# Round: 64 4.419 seconds
# Round: 65 4.193 seconds
# Round: 66 4.398 seconds
# Round: 67 4.226 seconds
# Round: 68 4.266 seconds
# Round: 69 4.121 seconds
# Round: 70 4.4 seconds
# Round: 71 4.204 seconds
# Round: 72 4.199 seconds
# Round: 73 4.179 seconds
# Round: 74 4.372 seconds
# Round: 75 4.228 seconds
# Round: 76 4.609 seconds
# Round: 77 4.056 seconds
# Round: 78 4.408 seconds
# Round: 79 4.185 seconds
# Round: 80 4.353 seconds
# Round: 81 4.347 seconds
# Round: 82 4.21 seconds
# Round: 83 4.216 seconds
# Round: 84 4.202 seconds
# Round: 85 4.17 seconds
# Round: 86 4.386 seconds
# Round: 87 3.971 seconds
# Round: 88 4.441 seconds
# Round: 89 4.153 seconds
# Round: 90 4.447 seconds
# Round: 91 4.317 seconds
# Round: 92 4.28 seconds
# Round: 93 4.14 seconds
# Round: 94 4.301 seconds
# Round: 95 4.299 seconds
# Round: 96 4.19 seconds
# Round: 97 4.317 seconds
# Round: 98 4.054 seconds
# Round: 99 4.25 seconds
# Round: 100 4.255 seconds
# Done!

# %%
N = 10
bond_dims  = [2,4,8,16,32,64,999]
runs = 1

t = time.time()
dims = [2] * N
D = prod(dims)
NAs = np.arange(2, N+1)
for bond_dim in bond_dims:
    if bond_dim == 999:
        randket= rand_haar_state(D)

    else:
        randket= rand_matrix_product_state(N, bond_dim, phys_dim=2, dtype=complex, cyclic=True, trans_invar=False)

    for NA in NAs:
        NB = int(N - NA)
        
        randstate = ptr(randket, dims, np.arange(NA))
        NA1s = np.arange(1, NA)
        for NA1 in NA1s:
            NA2 = int(NA - NA1)

            LN = logneg_subsys(randket, dims, np.arange(NA1), np.arange(NA1,NA))
            
            randstate_pt = partial_transpose(randstate, [2] * NA, sysa=np.arange(NA1))
            r2 = np.dot(randstate_pt, randstate_pt)
            r3 = np.dot(r2, randstate_pt)
            r4 = np.dot(r3, randstate_pt)
            r5 = np.dot(r4, randstate_pt)
            r6 = np.dot(r5, randstate_pt)
            r7 = np.dot(r6, randstate_pt)
            r8 = np.dot(r7, randstate_pt)

            p2 = np.real(np.trace(r2))
            p3 = np.real(np.trace(r3))
            p4 = np.real(np.trace(r4))
            p5 = np.real(np.trace(r5))
            p6 = np.real(np.trace(r6))
            p7 = np.real(np.trace(r7))
            p8 = np.real(np.trace(r8))
                
                    
print('Round:',i+1, round(time.time()-t,3), 'seconds')
    
    
print("Done!")
# Out:
# Round: 1 11.574 seconds
# Done!

# %%
N = 10
bond_dims  = [2,4,8,16,32,64,999]
runs = 1

t = time.time()
dims = [2] * N
D = prod(dims)
NAs = np.arange(2, N+1)
for bond_dim in bond_dims:
    if bond_dim == 999:
        randket= rand_haar_state(D)

    else:
        randket= rand_matrix_product_state(N, bond_dim, phys_dim=2, dtype=complex, cyclic=True, trans_invar=False)

    for NA in NAs:
        NB = int(N - NA)
        randstate = ptr(randket, dims, np.arange(NA))
        if NA<N:
            NA1s = np.arange(1, NA)
            for NA1 in NA1s:
                NA2 = int(NA - NA1)


                LN = logneg_subsys(randket, dims, np.arange(NA1), np.arange(NA1,NA))

                randstate_pt = partial_transpose(randstate, [2] * NA, sysa=np.arange(NA1))
                r2 = np.dot(randstate_pt, randstate_pt)
                r3 = np.dot(r2, randstate_pt)
                r4 = np.dot(r3, randstate_pt)
                r5 = np.dot(r4, randstate_pt)
                r6 = np.dot(r5, randstate_pt)
                r7 = np.dot(r6, randstate_pt)
                r8 = np.dot(r7, randstate_pt)

                p2 = np.real(np.trace(r2))
                p3 = np.real(np.trace(r3))
                p4 = np.real(np.trace(r4))
                p5 = np.real(np.trace(r5))
                p6 = np.real(np.trace(r6))
                p7 = np.real(np.trace(r7))
                p8 = np.real(np.trace(r8))
        else:
            NA1s = np.arange(1, NA)
            for NA1 in NA1s:
                NA2 = int(NA - NA1)
                        
                LN = logneg_subsys(randket, dims, np.arange(NA1), np.arange(NA1,NA))

                rA1 = partial_trace(randstate, [2]*NA , keep=np.arange(NA1))
                r2 = np.dot(rA1, rA1)
                r3 = np.dot(r2, rA1)
                r4 = np.dot(r3, rA1)
                r5 = np.dot(r4, rA1)
                r6 = np.dot(r5, rA1)
                r7 = np.dot(r6, rA1)

                p2 = np.real(np.trace(randstate))
                p3 = np.real(np.trace(r3))
                p4 = np.real(np.trace(r2))**2
                p5 = np.real(np.trace(r5))
                p6 = np.real(np.trace(r3))**2
                p7 = np.real(np.trace(r7))
                p8 = np.real(np.trace(r4))**2
                
                    
                    
print('Round:',i+1, round(time.time()-t,3), 'seconds')
    
    
print("Done!")
# Out:
# Round: 1 4.363 seconds
# Done!

# %%
N = 12
bond_dims  = [2,4,8,16,32,64,999]
runs = 1

t = time.time()
dims = [2] * N
D = prod(dims)
NAs = np.arange(2, N)
for bond_dim in bond_dims:
    if bond_dim == 999:
        randket= rand_haar_state(D)

    else:
        randket= rand_matrix_product_state(N, bond_dim, phys_dim=2, dtype=complex, cyclic=True, trans_invar=False)

    for NA in NAs:

        randstate = ptr(randket, dims, np.arange(NA))
        NA1s = np.arange(1, NA)
        for NA1 in NA1s:
            NA2 = int(NA - NA1)
            NB = int(N - NA)

            randstate_pt = partial_transpose(randstate, [2] * NA, sysa=np.arange(NA1))

            eigs = np.linalg.eigvalsh(randstate_pt)
            LN = np.log(np.sum(np.abs(eigs)))
            p2 = np.sum(eigs*eigs)
            p3 = np.sum(eigs**3)
            p4 = np.sum(eigs**4)
            p5 = np.sum(eigs**5)
            p6 = np.sum(eigs**6)
            p7 = np.sum(eigs**7)
            p8 = np.sum(eigs**8)
print('Round:',i+1, round(time.time()-t,3), 'seconds')
    
    
print("Done!")
# Out:
# Round: 1 181.522 seconds
# Done!
