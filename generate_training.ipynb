# %%
import numpy as np
from quimb import *
import quimb.tensor as qtn
from quimb.tensor import *
import csv
import time

N = 10 # total number of qubits
bond_dims  = [2,4,8,16,32,64,999] #bond dimensions for random MPS; 999 means Haar random state

runs = 100 #number of runs for each state

with open('training_data_N_%d.csv' % (N), mode='a') as training_data:
    for i in np.arange(runs):
        t = time.time()
        dims = [2] * N
        D = prod(dims)
        NAs = np.arange(2, N+1)
        for bond_dim in bond_dims:
            if bond_dim == 999:
                randket= rand_haar_state(D)
            else:
                randket= rand_matrix_product_state(N, bond_dim, phys_dim=2, dtype=complex, cyclic=True, trans_invar=False)
            
            for NA in NAs:
                randstate = ptr(randket, dims, np.arange(NA))
                NA1s = np.arange(1, NA)
                for NA1 in NA1s:
                    NA2 = int(NA - NA1)
                    NB = int(N - NA)

                    randstate_pt = partial_transpose(randstate, [2] * NA, sysa=np.arange(NA1))

                    eigs = np.real(np.linalg.eigvals(randstate_pt))
                    LN = np.log(np.sum(np.abs(eigs)))
                    p2 = np.sum(eigs**2)
                    p3 = np.sum(eigs**3)
                    p4 = np.sum(eigs**4)
                    p5 = np.sum(eigs**5)
                    p6 = np.sum(eigs**6)
                    p7 = np.sum(eigs**7)
                    p8 = np.sum(eigs**8)

                    #Writing to file
                    training_writer = csv.writer(training_data, delimiter=',')
                    training_writer.writerow([NA1,NA2,NB,p2,p3,p4,p5,p6,p7,p8,LN])
                    
        print('Round:',i+1, round(time.time()-t,3), 'seconds')
    
    
print("Done!")
# Out:
# Round: 1 181.868 seconds
# Round: 2 178.895 seconds
# Round: 3 177.921 seconds
# Round: 4 179.406 seconds
# Round: 5 183.383 seconds
# Round: 6 188.046 seconds
# Round: 8 176.838 seconds
# Round: 9 183.47 seconds
# Round: 10 180.377 seconds
# Round: 11 178.7 seconds
# Round: 12 182.983 seconds
# Round: 13 188.258 seconds
# Round: 14 171.825 seconds
# Round: 15 178.59 seconds
# Round: 16 175.524 seconds
# Round: 17 173.624 seconds
# Round: 18 184.656 seconds
# Round: 19 179.801 seconds
# Round: 20 181.278 seconds
# Round: 21 179.811 seconds
# Round: 22 181.568 seconds
# Round: 23 176.798 seconds
# Round: 24 182.645 seconds
# Round: 25 181.115 seconds
# Round: 26 175.102 seconds
# Round: 27 180.028 seconds
# Round: 28 178.266 seconds
# Round: 29 173.727 seconds
# Round: 30 171.37 seconds
# Round: 31 165.98 seconds
# Round: 32 198.45 seconds
# Round: 33 172.501 seconds
# Round: 34 187.39 seconds
# Round: 35 168.675 seconds
# Round: 36 172.565 seconds
# Round: 37 178.366 seconds
# Round: 38 173.012 seconds
# Round: 39 172.228 seconds
# Round: 40 171.989 seconds
# Round: 41 182.899 seconds
# Round: 42 183.963 seconds
# Round: 43 173.036 seconds
# Round: 44 181.63 seconds
# Round: 45 175.798 seconds
# Round: 46 171.133 seconds
# Round: 47 173.603 seconds
# Round: 48 178.683 seconds
# Round: 49 179.73 seconds
# Round: 50 173.357 seconds
# Round: 51 181.814 seconds
# Round: 52 178.251 seconds
# Round: 53 186.4 seconds
# Round: 54 172.012 seconds
# Round: 55 192.536 seconds
# Round: 56 167.812 seconds
# Round: 57 170.64 seconds
# Round: 58 181.985 seconds
# Round: 59 180.185 seconds
# Round: 60 185.421 seconds
# Round: 61 181.247 seconds
# Round: 62 175.159 seconds
# Round: 63 177.059 seconds
# Round: 64 182.212 seconds
# Round: 65 182.004 seconds
# Round: 66 173.577 seconds
# Round: 67 174.592 seconds
# Round: 69 177.194 seconds
# Round: 70 174.521 seconds
# Round: 71 186.323 seconds
# Round: 72 195.657 seconds
# Round: 73 191.625 seconds
# Round: 74 177.508 seconds
# Round: 75 184.462 seconds
# Round: 76 178.357 seconds
# Round: 77 187.916 seconds
# Round: 78 182.825 seconds
# Round: 79 191.163 seconds
# Round: 80 176.484 seconds
# Round: 81 185.119 seconds
# Round: 82 189.196 seconds
# Round: 83 193.416 seconds
# Round: 84 184.207 seconds
# Round: 85 178.125 seconds
# Round: 86 180.332 seconds
# Round: 87 192.409 seconds
# Round: 88 179.303 seconds
# Round: 89 183.513 seconds
# Round: 90 194.029 seconds
# Round: 91 195.077 seconds
# Round: 92 193.892 seconds
# Round: 93 172.816 seconds
# Round: 94 167.276 seconds
# Round: 95 184.897 seconds
# Round: 96 180.515 seconds
# Round: 97 170.902 seconds
# Round: 98 192.639 seconds
# Round: 99 185.503 seconds
# Round: 100 189.516 seconds
# Done!
