# %%
import numpy as np
from quimb import *
import quimb.tensor as qtn
from quimb.tensor import *
import csv
import time
from numpy.linalg import matrix_power

# %%
N = 14
bond_dims  = [8,64,99] #[2,4,8,16,32,64,999]
runs = 100

with open('training_data_N_%d_eff.csv' % (N), mode='a') as training_data:
 
    for i in np.arange(runs):
        t = time.time()
        dims = [2] * N
        D = prod(dims)
        NAs = np.arange(2, N+1)
        for bond_dim in bond_dims:
            if bond_dim == 999:
                
                randket= rand_haar_state(D)
            
            else:
                randket= rand_matrix_product_state(N, bond_dim, phys_dim=2, dtype=complex, cyclic=True, trans_invar=False)
            
            for NA in NAs:
                NB = int(N - NA)
                randstate = ptr(randket, dims, np.arange(NA))
                if NA<N:
                    NA1s = np.arange(1, NA)
                    for NA1 in NA1s:
                        NA2 = int(NA - NA1)

                        LN = logneg_subsys(randket, dims, np.arange(NA1), np.arange(NA1,NA))

                        randstate_pt = partial_transpose(randstate, [2] * NA, sysa=np.arange(NA1))
                        r2 = np.dot(randstate_pt, randstate_pt)
                        r3 = np.dot(r2, randstate_pt)
                        r4 = np.dot(r3, randstate_pt)
                        r5 = np.dot(r4, randstate_pt)
                        r6 = np.dot(r5, randstate_pt)
                        r7 = np.dot(r6, randstate_pt)
                        r8 = np.dot(r7, randstate_pt)

                        p2 = np.real(np.trace(r2))
                        p3 = np.real(np.trace(r3))
                        p4 = np.real(np.trace(r4))
                        p5 = np.real(np.trace(r5))
                        p6 = np.real(np.trace(r6))
                        p7 = np.real(np.trace(r7))
                        p8 = np.real(np.trace(r8))
                        
                        #Writing to file
                        training_writer = csv.writer(training_data, delimiter=',')
                        training_writer.writerow([NA1,NA2,NB,p2,p3,p4,p5,p6,p7,p8,LN])
                else:
                    NA1s = np.arange(1, NA)
                    for NA1 in NA1s:
                        NA2 = int(NA - NA1)

                        LN = logneg_subsys(randket, dims, np.arange(NA1), np.arange(NA1,NA))

                        rA1 = partial_trace(randstate, [2]*NA , keep=np.arange(NA1))
                        r2 = np.dot(rA1, rA1)
                        r3 = np.dot(r2, rA1)
                        r4 = np.dot(r3, rA1)
                        r5 = np.dot(r4, rA1)
                        r6 = np.dot(r5, rA1)
                        r7 = np.dot(r6, rA1)

                        p2 = np.real(np.trace(rA1))
                        p3 = np.real(np.trace(r3))
                        p4 = np.real(np.trace(r2))**2
                        p5 = np.real(np.trace(r5))
                        p6 = np.real(np.trace(r3))**2
                        p7 = np.real(np.trace(r7))
                        p8 = np.real(np.trace(r4))**2
                
                    
                        #Writing to file
                        training_writer = csv.writer(training_data, delimiter=',')
                        training_writer.writerow([NA1,NA2,NB,p2,p3,p4,p5,p6,p7,p8,LN])

        print('Round:',i+1, round(time.time()-t,3), 'seconds')
    
    
print("Done!")
# Out:
# Round: 1 136.606 seconds
# Round: 2 136.751 seconds
# Round: 3 150.368 seconds
# Round: 4 136.501 seconds
# Round: 5 135.955 seconds
# Round: 6 136.607 seconds
# Round: 7 139.709 seconds
# Round: 8 138.755 seconds
# Round: 9 135.637 seconds
# Round: 10 137.191 seconds
# Round: 11 135.29 seconds
# Round: 12 152.816 seconds
# Round: 13 135.675 seconds
# Round: 14 135.062 seconds
# Round: 15 135.874 seconds
# Round: 16 136.317 seconds
# Round: 17 136.7 seconds
# Round: 18 135.581 seconds
# Round: 19 134.641 seconds
# Round: 20 135.586 seconds
# Round: 21 154.745 seconds
# Round: 22 135.065 seconds
# Round: 23 135.379 seconds
# Round: 24 135.494 seconds
# Round: 25 135.025 seconds
# Round: 26 134.498 seconds
# Round: 27 134.373 seconds
# Round: 28 135.654 seconds
# Round: 29 150.995 seconds
# Round: 30 136.801 seconds
# Round: 31 136.286 seconds
# Round: 32 134.471 seconds
# Round: 33 135.284 seconds
# Round: 34 136.146 seconds
# Round: 35 135.196 seconds
# Round: 36 135.491 seconds
# Round: 37 135.838 seconds
# Round: 38 153.47 seconds
# Round: 39 136.34 seconds
# Round: 40 137.229 seconds
# Round: 41 137.166 seconds
# Round: 42 138.329 seconds
# Round: 43 135.899 seconds
# Round: 44 135.43 seconds
# Round: 45 135.856 seconds
# Round: 46 135.412 seconds
# Round: 47 153.794 seconds
# Round: 48 135.52 seconds
# Round: 49 135.743 seconds
# Round: 50 136.22 seconds
# Round: 51 135.031 seconds
# Round: 52 137.064 seconds
# Round: 53 136.739 seconds
# Round: 54 135.769 seconds
# Round: 55 148.199 seconds
# Round: 56 139.495 seconds
# Round: 57 134.703 seconds
# Round: 58 134.939 seconds
# Round: 59 134.729 seconds
# Round: 60 136.271 seconds
# Round: 61 135.232 seconds
# Round: 62 135.652 seconds
# Round: 63 134.236 seconds
# Round: 64 151.93 seconds
# Round: 65 134.955 seconds
# Round: 66 133.28 seconds
# Round: 67 133.039 seconds
# Round: 68 134.84 seconds
# Round: 69 135.976 seconds
# Round: 70 134.134 seconds
# Round: 71 132.608 seconds
# Round: 72 135.385 seconds
# Round: 73 151.055 seconds
# Round: 74 137.585 seconds
# Round: 75 135.949 seconds
# Round: 76 135.644 seconds
# Round: 77 134.272 seconds
# Round: 78 135.656 seconds
# Round: 79 133.408 seconds
# Round: 80 136.243 seconds
# Round: 81 134.343 seconds
# Round: 82 152.171 seconds
# Round: 83 136.576 seconds
# Round: 84 135.166 seconds
# Round: 85 133.217 seconds
# Round: 87 133.501 seconds
# Round: 88 133.828 seconds
# Round: 89 133.925 seconds
# Round: 90 140.148 seconds
# Round: 91 148.969 seconds
# Round: 92 135.348 seconds
# Round: 93 134.409 seconds
# Round: 94 134.285 seconds
# Round: 95 135.602 seconds
# Round: 96 134.523 seconds
# Round: 97 134.358 seconds
# Round: 98 134.525 seconds
# Round: 99 150.828 seconds
# Round: 100 136.555 seconds
# Done!
